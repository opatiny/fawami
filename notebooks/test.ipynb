# %% [markdown]
# # This is a test notebook

# %%
import numpy as np

def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)


np.random.seed(0)
ran = np.random.rand()

print(factorial(5))
print(ran)
